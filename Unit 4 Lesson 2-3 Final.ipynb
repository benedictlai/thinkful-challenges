# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import cycle
from sklearn import metrics
from sklearn.cluster import AffinityPropagation, KMeans, MiniBatchKMeans, MeanShift, estimate_bandwidth, SpectralClustering
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
from sklearn.datasets.samples_generator import make_blobs
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %% [markdown]
# Set up at least three different blob configurations, then run the four methods ( 𝑘 -means, mean shift, spectral clustering and affinity propagation) on each one. Write up a report for your mentor where you discuss what you learned about the clustering methods based on their relative performance for your different blob setups.

# %% [markdown]
# # Blob Configuration #1:
#
# 20,000 rows standard deviation: 1

# %%
centers = [[2, 2], [-2, -2], [2, -2]]

X, y = make_blobs(
    n_samples=20000,
    centers=centers,
    cluster_std=1,
    n_features=2,
    random_state=42)

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.9,
    random_state=42)

# %% [markdown]
# # K-means

# %%
y_pred = KMeans(n_clusters=3, random_state=42).fit_predict(X_train)

# Plot the solution.
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_pred)
plt.show()

# Check the solution against the data.
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_train, y_pred))
# Out:
# Comparing k-means clusters against the data:
# col_0    0    1    2
# row_0
# 0        0  656   11
# 1      645    2   16
# 2        9   12  649

# %% [markdown]
# # Mean-shift

# %%
bandwidth = estimate_bandwidth(X_train, quantile=0.2, n_samples=500)

ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X_train)

labels = ms.labels_

cluster_centers = ms.cluster_centers_

n_clusters_ = len(np.unique(labels))

print("# of estimated clusters: {}".format(n_clusters_))
# Out:
# # of estimated clusters: 3

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=labels)
plt.show()

print('Comparing the assigned categories to the ones in the data:')
print(pd.crosstab(y_train,labels))
# Out:
# Comparing the assigned categories to the ones in the data:
# col_0    0    1    2
# row_0
# 0       12    0  655
# 1       16  645    2
# 2      648    9   13

# %% [markdown]
# # Spectral Clustering

# %%
n_clusters=3

sc = SpectralClustering(n_clusters=n_clusters)
sc.fit(X_train)

predict=sc.fit_predict(X_train)

plt.scatter(X_train[:, 0], X_train[:, 1], c=predict)
plt.show()

print('Comparing the assigned categories to the ones in the data:')
print(pd.crosstab(y_train,predict))
# Out:
# Comparing the assigned categories to the ones in the data:
# col_0    0    1    2
# row_0
# 0        0  653   14
# 1      642    3   18
# 2        8   13  649

# %% [markdown]
# # Affinity Propagation

# %%
af = AffinityPropagation().fit(X_train)
print('Done')

cluster_centers_indices = af.cluster_centers_indices_
n_clusters_ = len(cluster_centers_indices)
labels = af.labels_

print('Estimated number of clusters: {}'.format(n_clusters_))
# Out:
# Done
# Estimated number of clusters: 302

# %%
plt.figure(1)
plt.clf()

colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
for k, col in zip(range(n_clusters_), colors):
    class_members = labels == k
    cluster_center = X_train[cluster_centers_indices[k]]
    plt.plot(X_train[class_members, 0], X_train[class_members, 1], col + '.')
    plt.plot(cluster_center[0],
             cluster_center[1],
             'o',
             markerfacecolor=col,
             markeredgecolor='k')
    for x in X_train[class_members]:
        plt.plot([cluster_center[0], x[0]], [cluster_center[1], x[1]], col)

plt.title('Estimated number of clusters: {}'.format(n_clusters_))
plt.show()

# %% [markdown]
# # Blob Configuration #2:
#
# 25,000 rows standard deviation: 2

# %%
centers = [[2, 2], [-2, -2], [2, -2]]

X, y = make_blobs(
    n_samples=25000,
    centers=centers,
    cluster_std=2,
    n_features=2,
    random_state=42)

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.9,
    random_state=42)

# %% [markdown]
# # K - Means

# %%
y_pred = KMeans(n_clusters=3, random_state=42).fit_predict(X_train)

# Plot the solution.
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_pred)
plt.show()

# Check the solution against the data.
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_train, y_pred))
# Out:
# Comparing k-means clusters against the data:
# col_0    0    1    2
# row_0
# 0       61  661  118
# 1      686   42  127
# 2      118  119  568

# %% [markdown]
# # Mean-shift

# %%
bandwidth = estimate_bandwidth(X_train, quantile=0.2, n_samples=500)

ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X_train)

labels = ms.labels_

cluster_centers = ms.cluster_centers_

n_clusters_ = len(np.unique(labels))

print("# of estimated clusters: {}".format(n_clusters_))
# Out:
# # of estimated clusters: 1

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=labels)
plt.show()

print('Comparing the assigned categories to the ones in the data:')
print(pd.crosstab(y_train,labels))
# Out:
# Comparing the assigned categories to the ones in the data:
# col_0    0
# row_0
# 0      840
# 1      855
# 2      805

# %% [markdown]
# # Spectral Clustering

# %%
n_clusters=3

sc = SpectralClustering(n_clusters=n_clusters)
sc.fit(X_train)

predict=sc.fit_predict(X_train)

plt.scatter(X_train[:, 0], X_train[:, 1], c=predict)
plt.show()

print('Comparing the assigned categories to the ones in the data:')
print(pd.crosstab(y_train,predict))
# Out:
# Comparing the assigned categories to the ones in the data:
# col_0    0    1    2
# row_0
# 0      176   47  617
# 1      202  618   35
# 2      649   70   86

# %% [markdown]
# # Affinity Propagation

# %%
af = AffinityPropagation().fit(X_train)
print('Done')

cluster_centers_indices = af.cluster_centers_indices_
n_clusters_ = len(cluster_centers_indices)
labels = af.labels_

print('Estimated number of clusters: {}'.format(n_clusters_))
# Out:
# Done
# Estimated number of clusters: 530

# %%
plt.figure(1)
plt.clf()

colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
for k, col in zip(range(n_clusters_), colors):
    class_members = labels == k
    cluster_center = X_train[cluster_centers_indices[k]]
    plt.plot(X_train[class_members, 0], X_train[class_members, 1], col + '.')
    plt.plot(cluster_center[0],
             cluster_center[1],
             'o',
             markerfacecolor=col,
             markeredgecolor='k')
    for x in X_train[class_members]:
        plt.plot([cluster_center[0], x[0]], [cluster_center[1], x[1]], col)

plt.title('Estimated number of clusters: {}'.format(n_clusters_))
plt.show()

# %% [markdown]
# # Blob Configuration #3:
#
# 15,000 rows standard deviation: 3

# %%
centers = [[2, 2], [-2, -2], [2, -2]]

X, y = make_blobs(
    n_samples=15000,
    centers=centers,
    cluster_std=3,
    n_features=2,
    random_state=42)

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.9,
    random_state=42)

# %% [markdown]
# # K-Means

# %%
y_pred = KMeans(n_clusters=3, random_state=42).fit_predict(X_train)

# Plot the solution.
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_pred)
plt.show()

# Check the solution against the data.
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_train, y_pred))
# Out:
# Comparing k-means clusters against the data:
# col_0    0    1    2
# row_0
# 0       82  352   59
# 1       95   65  353
# 2      287  106  101

# %% [markdown]
# # Mean-Shift

# %%
bandwidth = estimate_bandwidth(X_train, quantile=0.2, n_samples=500)

ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X_train)

labels = ms.labels_

cluster_centers = ms.cluster_centers_

n_clusters_ = len(np.unique(labels))

print("# of estimated clusters: {}".format(n_clusters_))
# Out:
# # of estimated clusters: 1

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=labels)
plt.show()

print('Comparing the assigned categories to the ones in the data:')
print(pd.crosstab(y_train,labels))
# Out:
# Comparing the assigned categories to the ones in the data:
# col_0    0
# row_0
# 0      493
# 1      513
# 2      494

# %% [markdown]
# # Spectral Clustering

# %%
n_clusters=3

sc = SpectralClustering(n_clusters=n_clusters)
sc.fit(X_train)

predict=sc.fit_predict(X_train)

plt.scatter(X_train[:, 0], X_train[:, 1], c=predict)
plt.show()

print('Comparing the assigned categories to the ones in the data:')
print(pd.crosstab(y_train,predict))
# Out:
# Comparing the assigned categories to the ones in the data:
# col_0    0  1  2
# row_0
# 0      493  0  0
# 1      510  2  1
# 2      494  0  0

# %% [markdown]
# # Affinity Propagation

# %%
af = AffinityPropagation().fit(X_train)
print('Done')

cluster_centers_indices = af.cluster_centers_indices_
n_clusters_ = len(cluster_centers_indices)
labels = af.labels_

print('Estimated number of clusters: {}'.format(n_clusters_))
# Out:
# Done
# Estimated number of clusters: 204

# %%
plt.figure(1)
plt.clf()

colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
for k, col in zip(range(n_clusters_), colors):
    class_members = labels == k
    cluster_center = X_train[cluster_centers_indices[k]]
    plt.plot(X_train[class_members, 0], X_train[class_members, 1], col + '.')
    plt.plot(cluster_center[0],
             cluster_center[1],
             'o',
             markerfacecolor=col,
             markeredgecolor='k')
    for x in X_train[class_members]:
        plt.plot([cluster_center[0], x[0]], [cluster_center[1], x[1]], col)

plt.title('Estimated number of clusters: {}'.format(n_clusters_))
plt.show()

# %% [markdown]
# # Blob Configuration #4:
#
# 10,000 rows standard deviation: 4

# %%
centers = [[2, 2], [-2, -2], [2, -2]]

X, y = make_blobs(
    n_samples=10000,
    centers=centers,
    cluster_std=4,
    n_features=2,
    random_state=42)

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.9,
    random_state=42)

# %% [markdown]
# # K-Means

# %%
y_pred = KMeans(n_clusters=3, random_state=42).fit_predict(X_train)

# Plot the solution.
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_pred)
plt.show()

# Check the solution against the data.
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_train, y_pred))
# Out:
# Comparing k-means clusters against the data:
# col_0    0    1    2
# row_0
# 0      192   46  124
# 1       57  149  114
# 2      146  111   61

# %% [markdown]
# # Mean-Shift

# %%
bandwidth = estimate_bandwidth(X_train, quantile=0.2, n_samples=500)

ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X_train)

labels = ms.labels_

cluster_centers = ms.cluster_centers_

n_clusters_ = len(np.unique(labels))

print("# of estimated clusters: {}".format(n_clusters_))
# Out:
# # of estimated clusters: 1

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=labels)
plt.show()

print('Comparing the assigned categories to the ones in the data:')
print(pd.crosstab(y_train,labels))
# Out:
# Comparing the assigned categories to the ones in the data:
# col_0    0
# row_0
# 0      362
# 1      320
# 2      318

# %% [markdown]
# # Spectral Clustering

# %%
n_clusters=3

sc = SpectralClustering(n_clusters=n_clusters)
sc.fit(X_train)

predict=sc.fit_predict(X_train)

plt.scatter(X_train[:, 0], X_train[:, 1], c=predict)
plt.show()

print('Comparing the assigned categories to the ones in the data:')
print(pd.crosstab(y_train,predict))
# Out:
# Comparing the assigned categories to the ones in the data:
# col_0  0  1    2
# row_0
# 0      0  0  362
# 1      6  2  312
# 2      0  0  318

# %% [markdown]
# # Affinity Propagation

# %%
af = AffinityPropagation().fit(X_train)
print('Done')

cluster_centers_indices = af.cluster_centers_indices_
n_clusters_ = len(cluster_centers_indices)
labels = af.labels_

print('Estimated number of clusters: {}'.format(n_clusters_))
# Out:
# Done
# Estimated number of clusters: 72

# %%
plt.figure(1)
plt.clf()

colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
for k, col in zip(range(n_clusters_), colors):
    class_members = labels == k
    cluster_center = X_train[cluster_centers_indices[k]]
    plt.plot(X_train[class_members, 0], X_train[class_members, 1], col + '.')
    plt.plot(cluster_center[0],
             cluster_center[1],
             'o',
             markerfacecolor=col,
             markeredgecolor='k')
    for x in X_train[class_members]:
        plt.plot([cluster_center[0], x[0]], [cluster_center[1], x[1]], col)

plt.title('Estimated number of clusters: {}'.format(n_clusters_))
plt.show()
